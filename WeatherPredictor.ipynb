# %% [markdown]
# ## 1.  Data Collection

# %%
import pandas as pd

# Load the dataset
file_path = '/content/GlobalWeatherRepository.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# 1                    66.2  Partly cloudy  ...                1.1
# 2                    73.4          Sunny  ...               10.4
# 3                    43.3  Light drizzle  ...                0.7
# 4                    78.8  Partly cloudy  ...              183.4
#
#    air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0              26.6                         1                          1
# 1               2.0                         1                          1
# 2              18.4                         1                          1
# 3               0.9                         1                          1
# 4             262.3                         5                         10
#
#     sunrise    sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  04:50 AM  06:50 PM  12:12 PM  01:11 AM  Waxing Gibbous                 55
# 1  05:21 AM  07:54 PM  12:58 PM  02:14 AM  Waxing Gibbous                 55
# 2  05:40 AM  07:50 PM  01:15 PM  02:14 AM  Waxing Gibbous                 55
# 3  06:31 AM  09:11 PM  02:12 PM  03:31 AM  Waxing Gibbous                 55
# 4  06:12 AM  05:55 PM  01:17 PM  12:38 AM  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %%
# Create DataFrame
df = pd.DataFrame(data)

df
# Out:
#            country     location_name  latitude  longitude         timezone  \
# 0      Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1          Albania            Tirana     41.33      19.82    Europe/Tirane
# 2          Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3          Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4           Angola            Luanda     -8.84      13.23    Africa/Luanda
# ...            ...               ...       ...        ...              ...
# 13519    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 13520      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 13521        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 13522       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 13523     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#        last_updated_epoch      last_updated  temperature_celsius  \
# 0              1715849100  2024-05-16 13:15                 26.6
# 1              1715849100  2024-05-16 10:45                 19.0
# 2              1715849100  2024-05-16 09:45                 23.0
# 3              1715849100  2024-05-16 10:45                  6.3
# 4              1715849100  2024-05-16 09:45                 26.0
# ...                   ...               ...                  ...
# 13519          1721910600  2024-07-25 08:30                 20.9
# 13520          1721910600  2024-07-25 19:30                 30.4
# 13521          1721910600  2024-07-25 15:30                 21.4
# 13522          1721910600  2024-07-25 14:30                 29.5
# 13523          1721910600  2024-07-25 14:30                 27.3
#
#        temperature_fahrenheit                               condition_text  \
# 0                        79.8                                Partly Cloudy
# 1                        66.2                                Partly cloudy
# 2                        73.4                                        Sunny
# 3                        43.3                                Light drizzle
# 4                        78.8                                Partly cloudy
# ...                       ...                                          ...
# 13519                    69.6                                        Sunny
# 13520                    86.7                           Patchy rain nearby
# 13521                    70.6  Moderate or heavy rain in area with thunder
# 13522                    85.1                                        Sunny
# 13523                    81.1                                        Sunny
#
#        ...  air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0      ...                8.4              26.6                         1
# 1      ...                1.1               2.0                         1
# 2      ...               10.4              18.4                         1
# 3      ...                0.7               0.9                         1
# 4      ...              183.4             262.3                         5
# ...    ...                ...               ...                       ...
# 13519  ...               10.6              11.1                         1
# 13520  ...               46.5              70.0                         3
# 13521  ...               20.8              68.3                         2
# 13522  ...               22.4              30.7                         2
# 13523  ...               22.1              25.7                         2
#
#       air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 0                              1  04:50 AM  06:50 PM  12:12 PM  01:11 AM
# 1                              1  05:21 AM  07:54 PM  12:58 PM  02:14 AM
# 2                              1  05:40 AM  07:50 PM  01:15 PM  02:14 AM
# 3                              1  06:31 AM  09:11 PM  02:12 PM  03:31 AM
# 4                             10  06:12 AM  05:55 PM  01:17 PM  12:38 AM
# ...                          ...       ...       ...       ...       ...
# 13519                          1  06:15 AM  06:53 PM  10:35 PM  10:11 AM
# 13520                          5  05:28 AM  06:38 PM  09:44 PM  09:10 AM
# 13521                          2  05:44 AM  06:35 PM  09:57 PM  09:29 AM
# 13522                          2  06:32 AM  05:55 PM  10:04 PM  09:41 AM
# 13523                          2  06:25 AM  05:40 PM  09:53 PM  09:31 AM
#
#            moon_phase  moon_illumination
# 0      Waxing Gibbous                 55
# 1      Waxing Gibbous                 55
# 2      Waxing Gibbous                 55
# 3      Waxing Gibbous                 55
# 4      Waxing Gibbous                 55
# ...               ...                ...
# 13519  Waning Gibbous                 83
# 13520  Waning Gibbous                 83
# 13521  Waning Gibbous                 83
# 13522  Waning Gibbous                 83
# 13523  Waning Gibbous                 83
#
# [13524 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13524 entries, 0 to 13523
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       13524 non-null  object
#  1   location_name                 13524 non-null  object
#  2   latitude                      13524 non-null  float64
#  3   longitude                     13524 non-null  float64
#  4   timezone                      13524 non-null  object
#  5   last_updated_epoch            13524 non-null  int64
#  6   last_updated                  13524 non-null  object
#  7   temperature_celsius           13524 non-null  float64
#  8   temperature_fahrenheit        13524 non-null  float64
#  9   condition_text                13524 non-null  object
#  10  wind_mph                      13524 non-null  float64
#  11  wind_kph                      13524 non-null  float64
#  12  wind_degree                   13524 non-null  int64
#  13  wind_direction                13524 non-null  object
#  14  pressure_mb                   13524 non-null  float64
#  15  pressure_in                   13524 non-null  float64
#  16  precip_mm                     13524 non-null  float64
#  17  precip_in                     13524 non-null  float64
#  18  humidity                      13524 non-null  int64
#  19  cloud                         13524 non-null  int64
#  20  feels_like_celsius            13524 non-null  float64
#  21  feels_like_fahrenheit         13524 non-null  float64
#  22  visibility_km                 13524 non-null  float64
#  23  visibility_miles              13524 non-null  float64
#  24  uv_index                      13524 non-null  float64
#  25  gust_mph                      13524 non-null  float64
#  26  gust_kph                      13524 non-null  float64
#  27  air_quality_Carbon_Monoxide   13524 non-null  float64
#  28  air_quality_Ozone             13524 non-null  float64
#  29  air_quality_Nitrogen_dioxide  13524 non-null  float64
#  30  air_quality_Sulphur_dioxide   13524 non-null  float64
#  31  air_quality_PM2.5             13524 non-null  float64
#  32  air_quality_PM10              13524 non-null  float64
#  33  air_quality_us-epa-index      13524 non-null  int64
#  34  air_quality_gb-defra-index    13524 non-null  int64
#  35  sunrise                       13524 non-null  object
#  36  sunset                        13524 non-null  object
#  37  moonrise                      13524 non-null  object
#  38  moonset                       13524 non-null  object
#  39  moon_phase                    13524 non-null  object
#  40  moon_illumination             13524 non-null  int64
# dtypes: float64(23), int64(7), object(11)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  13524.000000  13524.000000        1.352400e+04         13524.000000
# mean      19.162719     21.826483        1.718756e+09            26.261653
# std       24.522021     65.770700        1.752397e+06             7.223333
# min      -41.300000   -175.200000        1.715849e+09            -3.700000
# 25%        3.750000     -6.840000        1.717251e+09            22.300000
# 50%       17.250000     23.320000        1.718719e+09            27.000000
# 75%       40.400000     49.880000        1.720272e+09            30.200000
# max       64.150000    179.220000        1.721911e+09            49.200000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            13524.000000  13524.000000  13524.000000  13524.000000
# mean                79.272294      8.923492     14.365506    178.112171
# std                 13.002451     16.755064     26.966052    100.677472
# min                 25.300000      2.200000      3.600000      1.000000
# 25%                 72.100000      4.300000      6.800000     94.000000
# 50%                 80.600000      8.100000     13.000000    178.000000
# 75%                 86.400000     11.900000     19.100000    260.000000
# max                120.600000   1841.200000   2963.200000    360.000000
#
#         pressure_mb   pressure_in  ...      gust_kph  \
# count  13524.000000  13524.000000  ...  13524.000000
# mean    1012.104999     29.886660  ...     21.968597
# std        6.221971      0.183302  ...     27.903685
# min      978.000000     28.890000  ...      3.600000
# 25%     1009.000000     29.800000  ...     13.400000
# 50%     1012.000000     29.890000  ...     20.200000
# 75%     1016.000000     30.000000  ...     27.800000
# max     1045.000000     30.860000  ...   2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 13524.000000       13524.000000
# mean                    493.020304          63.278076
# std                    1436.845252          44.048154
# min                   -9999.000000           0.000000
# 25%                     186.900000          29.000000
# 50%                     223.600000          58.700000
# 75%                     363.800000          91.600000
# max                   38879.398000         457.800000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  13524.000000                 13524.000000
# mean                       9.040912                     5.702203
# std                       23.129221                    87.463309
# min                        0.000000                 -9999.000000
# 25%                        0.500000                     0.400000
# 50%                        1.700000                     1.200000
# 75%                        5.600000                     4.300000
# max                      427.700000                   223.200000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       13524.000000      13524.000000              13524.000000
# mean           16.865114         30.688073                  1.354777
# std            60.910037         81.570885                  0.800419
# min             0.500000          0.500000                  1.000000
# 25%             2.000000          3.600000                  1.000000
# 50%             4.900000          8.800000                  1.000000
# 75%            14.000000         27.300000                  1.000000
# max          1614.100000       1814.400000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                13524.000000       13524.000000
# mean                     1.782387          54.467169
# std                      1.877419          34.580845
# min                      1.000000           0.000000
# 25%                      1.000000          21.000000
# 50%                      1.000000          58.000000
# 75%                      2.000000          88.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# ## 2. Data Preprocessing

# %%
# Convert 'last update' column to datetime
df['last_updated'] = pd.to_datetime(df['last_updated'])

# Check for missing values
print(df.isnull().sum())

# Handle missing values (example: fill with forward fill method)
df.fillna(method='ffill', inplace=True)

# Verify the changes
df.head()
df.info()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13524 entries, 0 to 13523
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       13524 non-null  object
#  1   location_name                 13524 non-null  object
#  2   latitude                      13524 non-null  float64
#  3   longitude                     13524 non-null  float64
#  4   timezone                      13524 non-null  object
#  5   last_updated_epoch            13524 non-null  int64
#  6   last_updated                  13524 non-null  datetime64[ns]
#  7   temperature_celsius           13524 non-null  float64
#  8   temperature_fahrenheit        13524 non-null  float64
#  9   condition_text                13524 non-null  object
#  10  wind_mph                      13524 non-null  float64
#  11  wind_kph                      13524 non-null  float64
#  12  wind_degree                   13524 non-null  int64
#  13  wind_direction                13524 non-null  object
#  14  pressure_mb                   13524 non-null  float64
#  15  pressure_in                   13524 non-null  float64
#  16  precip_mm                     13524 non-null  float64
#  17  precip_in                     13524 non-null  float64
#  18  humidity                      13524 non-null  int64
#  19  cloud                         13524 non-null  int64
#  20  feels_like_celsius            13524 non-null  float64
#  21  feels_like_fahrenheit         13524 non-null  float64
#  22  visibility_km                 13524 non-null  float64
#  23  visibility_miles              13524 non-null  float64
#  24  uv_index                      13524 non-null  float64
#  25  gust_mph                      13524 non-null  float64
#  26  gust_kph                      13524 non-null  float64
#  27  air_quality_Carbon_Monoxide   13524 non-null  float64
#  28  air_quality_Ozone             13524 non-null  float64
#  29  air_quality_Nitrogen_dioxide  13524 non-null  float64
#  30  air_quality_Sulphur_dioxide   13524 non-null  float64
#  31  air_quality_PM2.5             13524 non-null  float64
#  32  air_quality_PM10              13524 non-null  float64
#  33  air_quality_us-epa-index      13524 non-null  int64
#  34  air_quality_gb-defra-index    13524 non-null  int64
#  35  sunrise                       13524 non-null  object
#  36  sunset                        13524 non-null  object
#  37  moonrise                      13524 non-null  object
#  38  moonset                       13524 non-null  object
#  39  moon_phase                    13524 non-null  object
#  40  moon_illumination             13524 non-null  int64
# dtypes: datetime64[ns](1), float64(23), int64(7), object(10)
# memory usage: 4.2+ MB

# %% [markdown]
# ## 3. Exploratory Data Analysis(EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the temperature over time for a specific country (example: 'New York')
country = 'India'
country_data = df[df['country'] == country]

plt.figure(figsize=(15, 6))
plt.plot(country_data['last_updated'], country_data['temperature_celsius'], label=country)
plt.xlabel('Date')
plt.ylabel('temperature_celsius')
plt.title(f'Temperature over Time for {country}')
plt.legend()
plt.show()

# Distribution of temperature
sns.histplot(df['temperature_celsius'], kde=True)
plt.title('Temperature Distribution')
plt.show()

# %% [markdown]
# ## 4. Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# Assuming we are forecasting for one specific country
country = 'India'
country_data = df[df['country'] == country]

# Set the 'last_updated' column as the index
country_data.set_index('last_updated', inplace=True)

# Split the data
train_size = int(len(country_data) * 0.8)
train_data, test_data = country_data[:train_size], country_data[train_size:]

print(train_data.shape, test_data.shape)
# Out:
# (54, 40) (14, 40)

# %% [markdown]
# ##  5. Modeling

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the model
model = ARIMA(train_data['temperature_celsius'], order=(5, 1, 0))
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     temperature_celsius   No. Observations:                   54
# Model:                  ARIMA(5, 1, 0)   Log Likelihood                -131.906
# Date:                 Fri, 26 Jul 2024   AIC                            275.812
# Time:                         05:51:07   BIC                            287.634
# Sample:                              0   HQIC                           280.358
#                                   - 54
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4344      0.174     -2.498      0.012      -0.775      -0.094
# ar.L2         -0.3913      0.155     -2.529      0.011      -0.695      -0.088
# ar.L3         -0.1714      0.133     -1.288      0.198      -0.432       0.089
# ar.L4         -0.4272      0.139     -3.068      0.002      -0.700      -0.154
# ar.L5         -0.0117      0.204     -0.057      0.954      -0.412       0.389
# sigma2         8.3258      1.555      5.354      0.000       5.278      11.374
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 6.38
# Prob(Q):                              0.86   Prob(JB):                         0.04
# Heteroskedasticity (H):               2.02   Skew:                            -0.65
# Prob(H) (two-sided):                  0.14   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ##  6. Evaluate the Model

# %%
from sklearn.metrics import mean_squared_error

# Make predictions
predictions = model_fit.forecast(steps=len(test_data))

# Evaluate the model
mse = mean_squared_error(test_data['temperature_celsius'], predictions)
print(f'Mean Squared Error: {mse}')

# Plot the predictions
plt.figure(figsize=(15, 6))
plt.plot(train_data['temperature_celsius'], label='Training Data')
plt.plot(test_data['temperature_celsius'], label='Test Data')
plt.plot(test_data.index, predictions, label='Predictions', color='red')
plt.xlabel('Date')
plt.ylabel('temperature_celsius')
plt.title(f'Temperature Predictions for {country}')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 33.60590309358686
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ## 7. Forecast Future Temperatures

# %%
# Forecast future temperatures
future_steps = 30  # Example: Forecasting for the next 30 days
future_forecast = model_fit.forecast(steps=future_steps)

# Plot the future forecast
plt.figure(figsize=(15, 6))
plt.plot(country_data['temperature_celsius'], label='Historical Data')
plt.plot(pd.date_range(start=country_data.index[-1], periods=future_steps, freq='D'), future_forecast, label='Future Forecast', color='green')
plt.xlabel('Date')
plt.ylabel('temperature_celsius')
plt.title(f'Future Temperature Forecast for {country}')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ## SARIMA

# %% [markdown]
# ## 1.  Fit the SARIMA Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMA model
sarima_model = SARIMAX(train_data['temperature_celsius'],
                       order=(1, 1, 1),
                       seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)

# Print the model summary
print(sarima_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                temperature_celsius   No. Observations:                   54
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -111.002
# Date:                            Fri, 26 Jul 2024   AIC                            232.003
# Time:                                    06:16:20   BIC                            240.571
# Sample:                                         0   HQIC                           235.123
#                                              - 54
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1686      0.303      0.556      0.578      -0.426       0.763
# ma.L1         -0.6638      0.207     -3.203      0.001      -1.070      -0.258
# ar.S.L12      -0.4063      0.656     -0.619      0.536      -1.692       0.880
# ma.S.L12      -0.1344      0.725     -0.185      0.853      -1.556       1.287
# sigma2        11.9204      2.625      4.542      0.000       6.776      17.064
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.64
# Prob(Q):                              0.85   Prob(JB):                         0.72
# Heteroskedasticity (H):               0.90   Skew:                            -0.20
# Prob(H) (two-sided):                  0.85   Kurtosis:                         3.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 2. Evaluate the SARIMA Model

# %%
from sklearn.metrics import mean_squared_error

# Make predictions
sarima_predictions = sarima_fit.predict(start=test_data.index[0], end=test_data.index[-1], dynamic=False)

# Evaluate the model
sarima_mse = mean_squared_error(test_data['temperature_celsius'], sarima_predictions)
print(f'SARIMA Mean Squared Error: {sarima_mse}')

# Plot the predictions
plt.figure(figsize=(15, 6))
plt.plot(train_data['temperature_celsius'], label='Training Data')
plt.plot(test_data['temperature_celsius'], label='Test Data')
plt.plot(test_data.index, sarima_predictions, label='SARIMA Predictions', color='red')
plt.xlabel('Date')
plt.ylabel('temperature_celsius')
plt.title(f'Temperature Predictions for {country}')
plt.legend()
plt.show()
# Out:
# SARIMA Mean Squared Error: 14.434894684101522

# %% [markdown]
# ## 3. Forecast Future Temperatures

# %%
# Forecast future temperatures
future_steps = 30  # Example: Forecasting for the next 30 days
sarima_forecast = sarima_fit.get_forecast(steps=future_steps)
sarima_forecast_index = pd.date_range(start=test_data.index[-1], periods=future_steps, freq='D')
sarima_forecast_values = sarima_forecast.predicted_mean

# Plot the future forecast
plt.figure(figsize=(15, 6))
plt.plot(country_data['temperature_celsius'], label='Historical Data')
plt.plot(sarima_forecast_index, sarima_forecast_values, label='SARIMA Future Forecast', color='green')
plt.xlabel('Date')
plt.ylabel('temperature_celsius')
plt.title(f'Future Temperature Forecast for {country}')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
